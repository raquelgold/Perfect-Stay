# %% [markdown]
# # Settings

# %% [markdown]
# ## Installations

# %%
# %pip install playwright nest_asyncio
dbutils.library.restartPython()
# Out:
# Collecting playwright
#   Obtaining dependency information for playwright from https://files.pythonhosted.org/packages/56/61/3a803cb5ae0321715bfd5247ea871d25b32c8f372aeb70550a90c5f586df/playwright-1.57.0-py3-none-manylinux1_x86_64.whl.metadata
#   Downloading playwright-1.57.0-py3-none-manylinux1_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: nest_asyncio in /databricks/python3/lib/python3.11/site-packages (1.5.6)
# Collecting pyee<14,>=13 (from playwright)
#   Obtaining dependency information for pyee<14,>=13 from https://files.pythonhosted.org/packages/9b/4d/b9add7c84060d4c1906abe9a7e5359f2a60f7a9a4f67268b2766673427d8/pyee-13.0.0-py3-none-any.whl.metadata
#   Downloading pyee-13.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting greenlet<4.0.0,>=3.1.1 (from playwright)
#   Obtaining dependency information for greenlet<4.0.0,>=3.1.1 from https://files.pythonhosted.org/packages/5c/ae/8d472e1f5ac5efe55c563f3eabb38c98a44b832602e12910750a7c025802/greenlet-3.3.1-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata
#   Downloading greenlet-3.3.1-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.7 kB)
# Requirement already satisfied: typing-extensions in /databricks/python3/lib/python3.11/site-packages (from pyee<14,>=13->playwright) (4.10.0)
# Downloading playwright-1.57.0-py3-none-manylinux1_x86_64.whl (46.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/46.0 MB ? eta -:--:--
#    ━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/46.0 MB 47.3 MB/s eta 0:00:01
#    ━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/46.0 MB 59.5 MB/s eta 0:00:01
#    ━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/46.0 MB 68.3 MB/s eta 0:00:01
#    ━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/46.0 MB 86.2 MB/s eta 0:00:01
#    ━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/46.0 MB 83.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 18.6/46.0 MB 118.1 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━ 24.5/46.0 MB 174.4 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━ 32.4/46.0 MB 191.3 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━ 38.8/46.0 MB 199.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 45.4/46.0 MB 176.4 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 46.0/46.0 MB 180.9 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 46.0/46.0 MB 180.9 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 46.0/46.0 MB 180.9 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 46.0/46.0 MB 180.9 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 46.0/46.0 MB 180.9 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 46.0/46.0 MB 180.9 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 46.0/46.0 MB 180.9 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 46.0/46.0 MB 180.9 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 46.0/46.0 MB 180.9 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 MB 25.3 MB/s eta 0:00:00
# Downloading greenlet-3.3.1-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (590 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/590.3 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.3/590.3 kB 49.7 MB/s eta 0:00:00
# Downloading pyee-13.0.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyee, greenlet, playwright
#   Attempting uninstall: greenlet
#     Found existing installation: greenlet 2.0.1
#     Not uninstalling greenlet at /databricks/python3/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-40c663ad-b78b-44de-b48b-5d7f57ee424c
#     Can't uninstall 'greenlet'. No files were found to uninstall.
# Successfully installed greenlet-3.3.1 playwright-1.57.0 pyee-13.0.0
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %% [markdown]
# ## Imports

# %%
import subprocess
import sys
import re
import asyncio
from datetime import datetime
from io import StringIO
import logging
from typing import Optional
import requests
import pandas as pd
from bs4 import BeautifulSoup
from playwright.async_api import async_playwright
import nest_asyncio

nest_asyncio.apply()

# %% [markdown]
# ## System Setup

# %%
# Installs browser binaries (Chromium) and necessary OS dependencies 

def install_playwright_system_deps():
    print("Starting Playwright system setup...")
    
    try:
        # Install the browser binaries
        print("Installing browsers...")
        subprocess.run([sys.executable, "-m", "playwright", "install"], check=True)
        
        # Install OS-level dependencies (replaces manual apt-get commands)
        print("Installing OS dependencies (install-deps)...")
        subprocess.run([sys.executable, "-m", "playwright", "install-deps"], check=True)
        
        print("Successfully installed Playwright and dependencies.")
        
    except subprocess.CalledProcessError as e:
        print(f"Error during installation: {e}")
        raise

install_playwright_system_deps()
# Out:
# Starting Playwright system setup...
# Installing browsers...
# Downloading Chromium 143.0.7499.4 (playwright build v1200) from https://cdn.playwright.dev/dbazure/download/playwright/builds/chromium/1200/chromium-linux.zip
# (node:6734) [DEP0169] DeprecationWarning: `url.parse()` behavior is not standardized and prone to errors that have security implications. Use the WHATWG URL API instead. CVEs are not issued for `url.parse()` vulnerabilities.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# |                                                                                |   0% of 164.7 MiB
# |■■■■■■■■                                                                        |  10% of 164.7 MiB
# |■■■■■■■■■■■■■■■■                                                                |  20% of 164.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■                                                        |  30% of 164.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                                |  40% of 164.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                        |  50% of 164.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                |  60% of 164.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                        |  70% of 164.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                |  80% of 164.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■        |  90% of 164.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■| 100% of 164.7 MiB
# Chromium 143.0.7499.4 (playwright build v1200) downloaded to /root/.cache/ms-playwright/chromium-1200
# Downloading Chromium Headless Shell 143.0.7499.4 (playwright build v1200) from https://cdn.playwright.dev/dbazure/download/playwright/builds/chromium/1200/chromium-headless-shell-linux.zip
# (node:6752) [DEP0169] DeprecationWarning: `url.parse()` behavior is not standardized and prone to errors that have security implications. Use the WHATWG URL API instead. CVEs are not issued for `url.parse()` vulnerabilities.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# |                                                                                |   0% of 109.7 MiB
# |■■■■■■■■                                                                        |  10% of 109.7 MiB
# |■■■■■■■■■■■■■■■■                                                                |  20% of 109.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■                                                        |  30% of 109.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                                |  40% of 109.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                        |  50% of 109.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                |  60% of 109.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                        |  70% of 109.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                |  80% of 109.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■        |  90% of 109.7 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■| 100% of 109.7 MiB
# Chromium Headless Shell 143.0.7499.4 (playwright build v1200) downloaded to /root/.cache/ms-playwright/chromium_headless_shell-1200
# Downloading Firefox 144.0.2 (playwright build v1497) from https://cdn.playwright.dev/dbazure/download/playwright/builds/firefox/1497/firefox-ubuntu-22.04.zip
# |                                                                                |   0% of 98.4 MiB
# (node:6771) [DEP0169] DeprecationWarning: `url.parse()` behavior is not standardized and prone to errors that have security implications. Use the WHATWG URL API instead. CVEs are not issued for `url.parse()` vulnerabilities.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# |■■■■■■■■                                                                        |  10% of 98.4 MiB
# |■■■■■■■■■■■■■■■■                                                                |  20% of 98.4 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■                                                        |  30% of 98.4 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                                |  40% of 98.4 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                        |  50% of 98.4 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                |  60% of 98.4 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                        |  70% of 98.4 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                |  80% of 98.4 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■        |  90% of 98.4 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■| 100% of 98.4 MiB
# Firefox 144.0.2 (playwright build v1497) downloaded to /root/.cache/ms-playwright/firefox-1497
# Downloading Webkit 26.0 (playwright build v2227) from https://cdn.playwright.dev/dbazure/download/playwright/builds/webkit/2227/webkit-ubuntu-22.04.zip
# (node:6782) [DEP0169] DeprecationWarning: `url.parse()` behavior is not standardized and prone to errors that have security implications. Use the WHATWG URL API instead. CVEs are not issued for `url.parse()` vulnerabilities.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# |                                                                                |   0% of 96.1 MiB
# |■■■■■■■■                                                                        |  10% of 96.1 MiB
# |■■■■■■■■■■■■■■■■                                                                |  20% of 96.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■                                                        |  30% of 96.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                                |  40% of 96.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                        |  50% of 96.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                |  60% of 96.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                        |  70% of 96.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                |  80% of 96.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■        |  90% of 96.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■| 100% of 96.1 MiB
# Webkit 26.0 (playwright build v2227) downloaded to /root/.cache/ms-playwright/webkit-2227
# Downloading FFMPEG playwright build v1011 from https://cdn.playwright.dev/dbazure/download/playwright/builds/ffmpeg/1011/ffmpeg-linux.zip
# |                                                                                |   0% of 2.3 MiB
# |■■■■■■■■                                                                        |  10% of 2.3 MiB
# (node:6793) [DEP0169] DeprecationWarning: `url.parse()` behavior is not standardized and prone to errors that have security implications. Use the WHATWG URL API instead. CVEs are not issued for `url.parse()` vulnerabilities.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# |■■■■■■■■■■■■■■■■                                                                |  20% of 2.3 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■                                                        |  30% of 2.3 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                                |  40% of 2.3 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                        |  50% of 2.3 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                |  60% of 2.3 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                        |  70% of 2.3 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                |  80% of 2.3 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■        |  90% of 2.3 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■| 100% of 2.3 MiB
# FFMPEG playwright build v1011 downloaded to /root/.cache/ms-playwright/ffmpeg-1011
# Playwright Host validation warning:
# ╔══════════════════════════════════════════════════════╗
# ║ Host system is missing dependencies to run browsers. ║
# ║ Missing libraries:                                   ║
# ║     libgtk-4.so.1                                    ║
# ║     libgraphene-1.0.so.0                             ║
# ║     libwoff2dec.so.1.0.2                             ║
# ║     libgstallocators-1.0.so.0                        ║
# ║     libgstapp-1.0.so.0                               ║
# ║     libgstpbutils-1.0.so.0                           ║
# ║     libgstaudio-1.0.so.0                             ║
# ║     libgsttag-1.0.so.0                               ║
# ║     libgstvideo-1.0.so.0                             ║
# ║     libgstgl-1.0.so.0                                ║
# ║     libgstcodecparsers-1.0.so.0                      ║
# ���     libgstfft-1.0.so.0                               ║
# ║     libwebpdemux.so.2                                ║
# ║     libavif.so.13                                    ║
# ║     libenchant-2.so.2                                ║
# ║     libsecret-1.so.0                                 ║
# ║     libhyphen.so.0                                   ║
# ║     libmanette-0.2.so.0                              ║
# ║     libGLESv2.so.2                                   ║
# ╚══════════════════════════════════════════════════════╝
#     at validateDependenciesLinux (/local_disk0/.ephemeral_nfs/envs/pythonEnv-40c663ad-b78b-44de-b48b-5d7f57ee424c/lib/python3.11/site-packages/playwright/driver/package/lib/server/registry/dependencies.js:269:9)
#     at process.processTicksAndRejections (node:internal/process/task_queues:103:5)
#     at async Registry._validateHostRequirements (/local_disk0/.ephemeral_nfs/envs/pythonEnv-40c663ad-b78b-44de-b48b-5d7f57ee424c/lib/python3.11/site-packages/playwright/driver/package/lib/server/registry/index.js:990:14)
#     at async Registry._validateHostRequirementsForExecutableIfNeeded (/local_disk0/.ephemeral_nfs/envs/pythonEnv-40c663ad-b78b-44de-b48b-5d7f57ee424c/lib/python3.11/site-packages/playwright/driver/package/lib/server/registry/index.js:1112:7)
#     at async Registry.validateHostRequirementsForExecutablesIfNeeded (/local_disk0/.ephemeral_nfs/envs/pythonEnv-40c663ad-b78b-44de-b48b-5d7f57ee424c/lib/python3.11/site-packages/playwright/driver/package/lib/server/registry/index.js:1101:7)
#     at async r.<anonymous> (/local_disk0/.ephemeral_nfs/envs/pythonEnv-40c663ad-b78b-44de-b48b-5d7f57ee424c/lib/python3.11/site-packages/playwright/driver/package/lib/cli/program.js:176:7)
# Installing OS dependencies (install-deps)...
# Installing dependencies...
# Get:1 https://repos.azul.com/zulu/deb stable InRelease [6538 B]
# Get:2 http://archive.ubuntu.com/ubuntu jammy InRelease [270 kB]
# Get:3 https://repos.azul.com/zulu/deb stable/main amd64 Packages [486 kB]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://repos.azul.com/zulu/deb stable/main arm64 Packages [325 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6288 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/restricted amd64 Packages [164 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 Packages [1792 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 Packages [266 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/universe amd64 Packages [17.5 MB]
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [62.6 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1293 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3640 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1605 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6498 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3971 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [70.9 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [37.2 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [83.9 kB]
# Fetched 44.7 MB in 4s (11.4 MB/s)
# Reading package lists...
# Reading package lists...
# W: https://repos.azul.com/zulu/deb/dists/stable/InRelease: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.
# Building dependency tree...
# Reading state information...
# libasound2 is already the newest version (1.2.6.1-1ubuntu1).
# libasound2 set to manually installed.
# libatk-bridge2.0-0 is already the newest version (2.38.0-3).
# libatk-bridge2.0-0 set to manually installed.
# libatk1.0-0 is already the newest version (2.36.0-3build1).
# libatk1.0-0 set to manually installed.
# libatspi2.0-0 is already the newest version (2.44.0-3).
# libatspi2.0-0 set to manually installed.
# libcairo-gobject2 is already the newest version (1.16.0-5ubuntu2).
# libcairo-gobject2 set to manually installed.
# libcairo2 is already the newest version (1.16.0-5ubuntu2).
# libcairo2 set to manually installed.
# libepoxy0 is already the newest version (1.5.10-1).
# libepoxy0 set to manually installed.
# libevent-2.1-7 is already the newest version (2.1.12-stable-1build3).
# libevent-2.1-7 set to manually installed.
# libfontconfig1 is already the newest version (2.13.1-4.2ubuntu5).
# libfontconfig1 set to manually installed.
# libglx0 is already the newest version (1.4.0-1).
# libglx0 set to manually installed.
# libicu70 is already the newest version (70.1-2).
# libicu70 set to manually installed.
# libjpeg-turbo8 is already the newest version (2.1.2-0ubuntu1).
# libjpeg-turbo8 set to manually installed.
# liblcms2-2 is already the newest version (2.12~rc1-2build2).
# liblcms2-2 set to manually installed.
# libopus0 is already the newest version (1.3.1-0.1build2).
# libopus0 set to manually installed.
# libxcb-shm0 is already the newest version (1.14-3ubuntu3).
# libxcb-shm0 set to manually installed.
# libxcb1 is already the newest version (1.14-3ubuntu3).
# libxcb1 set to manually installed.
# libxcomposite1 is already the newest version (1:0.4.5-1build2).
# libxcomposite1 set to manually installed.
# libxcursor1 is already the newest version (1:1.2.0-2build4).
# libxcursor1 set to manually installed.
# libxdamage1 is already the newest version (1:1.1.5-2build2).
# libxdamage1 set to manually installed.
# libxext6 is already the newest version (2:1.3.4-1build1).
# libxext6 set to manually installed.
# libxfixes3 is already the newest version (1:6.0.0-1).
# libxfixes3 set to manually installed.
# libxi6 is already the newest version (2:1.8-1build1).
# libxi6 set to manually installed.
# libxkbcommon0 is already the newest version (1.4.0-1).
# libxkbcommon0 set to manually installed.
# libxrandr2 is already the newest version (2:1.5.2-1build1).
# libxrandr2 set to manually installed.
# libxrender1 is already the newest version (1:0.9.10-1build4).
# libxrender1 set to manually installed.
# libxtst6 is already the newest version (2:1.2.3-1build4).
# libxtst6 set to manually installed.
# libffi7 is already the newest version (3.3-5ubuntu1).
# libx264-163 is already the newest version (2:0.163.3060+git5db6aa6-2build1).
# libx264-163 set to manually installed.
# libatomic1 is already the newest version (12.3.0-1ubuntu1~22.04.2).
# libatomic1 set to manually installed.
# libcups2 is already the newest version (2.4.1op1-1ubuntu4.16).
# libcups2 set to manually installed.
# libdbus-1-3 is already the newest version (1.12.20-2ubuntu4.1).
# libdbus-1-3 set to manually installed.
# libdrm2 is already the newest version (2.4.113-2~ubuntu0.22.04.1).
# libdrm2 set to manually installed.
# libfreetype6 is already the newest version (2.11.1+dfsg-1ubuntu0.3).
# libfreetype6 set to manually installed.
# libgbm1 is already the newest version (23.2.1-1ubuntu3.1~22.04.3).
# libgbm1 set to manually installed.
# libgdk-pixbuf-2.0-0 is already the newest version (2.42.8+dfsg-1ubuntu0.4).
# libgdk-pixbuf-2.0-0 set to manually installed.
# libgstreamer1.0-0 is already the newest version (1.20.3-0ubuntu1.1).
# libgstreamer1.0-0 set to manually installed.
# libgtk-3-0 is already the newest version (3.24.33-1ubuntu2.2).
# libgtk-3-0 set to manually installed.
# libharfbuzz-icu0 is already the newest version (2.7.4-1ubuntu3.2).
# libharfbuzz-icu0 set to manually installed.
# libharfbuzz0b is already the newest version (2.7.4-1ubuntu3.2).
# libharfbuzz0b set to manually installed.
# libnspr4 is already the newest version (2:4.35-0ubuntu0.22.04.1).
# libnspr4 set to manually installed.
# libnss3 is already the newest version (2:3.98-0ubuntu0.22.04.2).
# libnss3 set to manually installed.
# libopenjp2-7 is already the newest version (2.4.0-6ubuntu0.4).
# libopenjp2-7 set to manually installed.
# libpango-1.0-0 is already the newest version (1.50.6+ds-2ubuntu1).
# libpango-1.0-0 set to manually installed.
# libpangocairo-1.0-0 is already the newest version (1.50.6+ds-2ubuntu1).
# libpangocairo-1.0-0 set to manually installed.
# libwayland-client0 is already the newest version (1.20.0-1ubuntu0.1).
# libwayland-client0 set to manually installed.
# libwayland-egl1 is already the newest version (1.20.0-1ubuntu0.1).
# libwayland-egl1 set to manually installed.
# libwayland-server0 is already the newest version (1.20.0-1ubuntu0.1).
# libwayland-server0 set to manually installed.
# libx11-6 is already the newest version (2:1.7.5-1ubuntu0.3).
# libx11-6 set to manually installed.
# libx11-xcb1 is already the newest version (2:1.7.5-1ubuntu0.3).
# libx11-xcb1 set to manually installed.
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# ffmpeg is already the newest version (7:4.4.4-0ubuntu1~22.04.db1).
# The following additional packages will be installed:
#   dictionaries-common glib-networking glib-networking-common
#   glib-networking-services hunspell-en-us libaa1 libaspell15
#   libcairo-script-interpreter2 libcdparanoia0 libdca0 libde265-0 libdv4
#   libdvdnav4 libdvdread8 libegl-mesa0 libfaad2 libfluidsynth3 libfreeaptx0
#   libgav1-0 libglib2.0-bin libglib2.0-dev libglib2.0-dev-bin libgraphene-1.0-0
#   libgssdp-1.2-0 libgstreamer-plugins-bad1.0-0 libgstreamer-plugins-good1.0-0
#   libgtk-4-common libgupnp-1.2-1 libgupnp-igd-1.0-4 libhunspell-1.7-0
#   libilmbase25 libinstpatch-1.0-2 libjson-glib-1.0-0 libjson-glib-1.0-common
#   libkate1 libldacbt-enc2 libltc11 liblzo2-2 libmjpegutils-2.1-0 libmodplug1
#   libmpcdec6 libmpeg2encpp-2.1-0 libmplex2-2.1-0 libnice10 libopenexr25
#   libopenh264-6 libopenni2-0 liborc-0.4-0 libpng-dev libpng-tools libqrencode4
#   libsbc1 libsecret-common libshout3 libsoundtouch1 libsoup-3.0-common
#   libsoup2.4-1 libsoup2.4-common libspandsp2 libsrtp2-1 libtag1v5
#   libtag1v5-vanilla libtext-iconv-perl libv4l-0 libv4lconvert0 libvisual-0.4-0
#   libvo-aacenc0 libvo-amrwbenc0 libwavpack1 libwebrtc-audio-processing1
#   libwildmidi2 libxml2-dev libxslt1-dev libyuv0 libzbar0 libzxingcore1
#   timgm6mb-soundfont
# Suggested packages:
#   ispell | aspell | hunspell wordlist frei0r-plugins gvfs hunspell
#   openoffice.org-hunspell | openoffice.org-core aspell libdv-bin oss-compat
#   libdvdcss2 libenchant-2-voikko libgirepository1.0-dev libglib2.0-doc
#   libxml2-utils libvisual-0.4-plugins libgtk-4-media-gstreamer
#   | libgtk-4-media-ffmpeg gnome-shell | notification-daemon libwildmidi-config
#   fluid-soundfont-gm
# Recommended packages:
#   fonts-ipafont-mincho fonts-tlwg-loma gstreamer1.0-x aspell-en
#   | aspell-dictionary | aspell6a-dictionary enchant-2 gstreamer1.0-gl
#   libgtk-4-bin libmagickcore-6.q16-6-extra
# The following NEW packages will be installed:
#   dictionaries-common fonts-freefont-ttf fonts-ipafont-gothic fonts-liberation
#   fonts-noto-color-emoji fonts-tlwg-loma-otf fonts-unifont fonts-wqy-zenhei
#   glib-networking glib-networking-common glib-networking-services
#   gstreamer1.0-libav gstreamer1.0-plugins-bad gstreamer1.0-plugins-base
#   gstreamer1.0-plugins-good hunspell-en-us libaa1 libaspell15 libavif13
#   libcairo-script-interpreter2 libcdparanoia0 libdbus-glib-1-2 libdca0
#   libde265-0 libdv4 libdvdnav4 libdvdread8 libegl-mesa0 libegl1 libenchant-2-2
#   libevdev2 libfaad2 libfluidsynth3 libfreeaptx0 libgav1-0 libgles2
#   libgraphene-1.0-0 libgssdp-1.2-0 libgstreamer-gl1.0-0
#   libgstreamer-plugins-bad1.0-0 libgstreamer-plugins-base1.0-0
#   libgstreamer-plugins-good1.0-0 libgtk-4-1 libgtk-4-common libgudev-1.0-0
#   libgupnp-1.2-1 libgupnp-igd-1.0-4 libhunspell-1.7-0 libhyphen0 libilmbase25
#   libinstpatch-1.0-2 libjson-glib-1.0-0 libjson-glib-1.0-common libkate1
#   libldacbt-enc2 libltc11 liblzo2-2 libmanette-0.2-0 libmjpegutils-2.1-0
#   libmodplug1 libmpcdec6 libmpeg2encpp-2.1-0 libmplex2-2.1-0 libnice10
#   libnotify4 libopenexr25 libopengl0 libopenh264-6 libopenni2-0 liborc-0.4-0
#   libproxy1v5 libqrencode4 libsbc1 libsecret-1-0 libsecret-common libshout3
#   libsoundtouch1 libsoup-3.0-0 libsoup-3.0-common libsoup2.4-1
#   libsoup2.4-common libspandsp2 libsrtp2-1 libtag1v5 libtag1v5-vanilla
#   libtext-iconv-perl libv4l-0 libv4lconvert0 libvisual-0.4-0 libvo-aacenc0
#   libvo-amrwbenc0 libwavpack1 libwebpdemux2 libwebrtc-audio-processing1
#   libwildmidi2 libwoff1 libyuv0 libzbar0 libzxingcore1 timgm6mb-soundfont
#   xfonts-cyrillic xfonts-scalable
# The following packages will be upgraded:
#   libglib2.0-0 libglib2.0-bin libglib2.0-dev libglib2.0-dev-bin libpng-dev
#   libpng-tools libpng16-16 libxml2 libxml2-dev libxslt1-dev libxslt1.1
# 11 upgraded, 102 newly installed, 0 to remove and 59 not upgraded.
# Need to get 59.8 MB of archives.
# After this operation, 143 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-ipafont-gothic all 00303-21ubuntu1 [3513 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglib2.0-dev amd64 2.72.4-0ubuntu2.8 [1743 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglib2.0-dev-bin amd64 2.72.4-0ubuntu2.8 [117 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglib2.0-bin amd64 2.72.4-0ubuntu2.8 [80.9 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglib2.0-0 amd64 2.72.4-0ubuntu2.8 [1467 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtext-iconv-perl amd64 1.7-7build3 [14.3 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libxml2-dev amd64 2.9.13+dfsg-1ubuntu0.11 [805 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libxml2 amd64 2.9.13+dfsg-1ubuntu0.11 [765 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpng-dev amd64 1.6.37-3ubuntu0.3 [193 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpng-tools amd64 1.6.37-3ubuntu0.3 [28.7 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpng16-16 amd64 1.6.37-3ubuntu0.3 [192 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 dictionaries-common all 1.28.14 [185 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-freefont-ttf all 20120503-10build1 [2388 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-liberation all 1:1.07.4-11 [822 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 fonts-noto-color-emoji all 2.047-0ubuntu0.22.04.1 [10.0 MB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-tlwg-loma-otf all 1:0.7.3-1 [107 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-unifont all 1:14.0.01-1 [3551 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-wqy-zenhei all 0.9.45-8 [7472 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libproxy1v5 amd64 0.4.17-2 [51.9 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 glib-networking-common all 2.72.0-1 [3718 B]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 glib-networking-services amd64 2.72.0-1 [9982 B]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 glib-networking amd64 2.72.0-1 [69.8 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 liborc-0.4-0 amd64 1:0.4.32-2ubuntu0.1 [228 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgstreamer-plugins-base1.0-0 amd64 1.20.1-1ubuntu0.5 [848 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 gstreamer1.0-libav amd64 1.20.3-0ubuntu1 [103 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcdparanoia0 amd64 3.10.2+debian-14build2 [49.3 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvisual-0.4-0 amd64 0.4.0-17build2 [108 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gstreamer1.0-plugins-base amd64 1.20.1-1ubuntu0.5 [712 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libaa1 amd64 1.4p5-50build1 [51.9 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdv4 amd64 1.0.0-14build1 [61.9 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgstreamer-plugins-good1.0-0 amd64 1.20.3-0ubuntu1.4 [30.2 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgudev-1.0-0 amd64 1:237-2build1 [16.3 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 libshout3 amd64 2.4.5-1build3 [54.5 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtag1v5-vanilla amd64 1.11.1+dfsg.1-3ubuntu3 [304 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtag1v5 amd64 1.11.1+dfsg.1-3ubuntu3 [11.5 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/main amd64 libv4lconvert0 amd64 1.22.1-2build1 [82.4 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/main amd64 libv4l-0 amd64 1.22.1-2build1 [44.9 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwavpack1 amd64 5.4.0-1build2 [83.7 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsoup2.4-common all 2.74.2-3ubuntu0.6 [4778 B]
# Get:40 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsoup2.4-1 amd64 2.74.2-3ubuntu0.6 [288 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gstreamer1.0-plugins-good amd64 1.20.3-0ubuntu1.4 [2009 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/main amd64 hunspell-en-us all 1:2020.12.07-2 [280 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/main amd64 libaspell15 amd64 0.60.8-4build1 [325 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgav1-0 amd64 0.17.0-1build1 [336 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libyuv0 amd64 0.0~git20220104.b91df1a-2 [154 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libavif13 amd64 0.9.3-3 [69.5 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblzo2-2 amd64 2.10-2build3 [53.7 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcairo-script-interpreter2 amd64 1.16.0-5ubuntu2 [62.0 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdbus-glib-1-2 amd64 0.112-2build1 [65.4 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libde265-0 amd64 1.0.8-1ubuntu0.3 [290 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdvdread8 amd64 6.1.2-1 [55.7 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdvdnav4 amd64 6.1.1-1 [39.3 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libegl-mesa0 amd64 23.2.1-1ubuntu3.1~22.04.3 [118 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhunspell-1.7-0 amd64 1.7.0-4build1 [175 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy/main amd64 libenchant-2-2 amd64 2.3.2-1ubuntu2 [50.9 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfaad2 amd64 2.10.0-2 [197 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libinstpatch-1.0-2 amd64 1.1.6-1 [240 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy/universe amd64 timgm6mb-soundfont all 1.3-5 [5427 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfluidsynth3 amd64 2.2.5-1 [246 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfreeaptx0 amd64 0.1.1-1 [12.9 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgraphene-1.0-0 amd64 1.10.8-1 [48.2 kB]
# Get:62 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgssdp-1.2-0 amd64 1.4.0.1-2build1 [48.9 kB]
# Get:63 http://archive.ubuntu.com/ubuntu jammy/main amd64 libegl1 amd64 1.4.0-1 [28.6 kB]
# Get:64 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgstreamer-gl1.0-0 amd64 1.20.1-1ubuntu0.5 [204 kB]
# Get:65 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-4-common all 4.6.9+ds-0ubuntu0.22.04.2 [662 kB]
# Get:66 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-4-1 amd64 4.6.9+ds-0ubuntu0.22.04.2 [2866 kB]
# Get:67 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgupnp-1.2-1 amd64 1.4.3-1 [93.3 kB]
# Get:68 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgupnp-igd-1.0-4 amd64 1.2.0-1build1 [16.8 kB]
# Get:69 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhyphen0 amd64 2.8.8-7build2 [28.2 kB]
# Get:70 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libilmbase25 amd64 2.5.7-2 [175 kB]
# Get:71 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjson-glib-1.0-common all 1.6.6-1build1 [4432 B]
# Get:72 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjson-glib-1.0-0 amd64 1.6.6-1build1 [69.9 kB]
# Get:73 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libkate1 amd64 0.4.1-11build1 [39.4 kB]
# Get:74 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libldacbt-enc2 amd64 2.0.2.3+git20200429+ed310a0-4 [24.6 kB]
# Get:75 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libltc11 amd64 1.3.1-1 [12.3 kB]
# Get:76 http://archive.ubuntu.com/ubuntu jammy/main amd64 libevdev2 amd64 1.12.1+dfsg-1 [39.5 kB]
# Get:77 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmanette-0.2-0 amd64 0.2.6-3build1 [30.4 kB]
# Get:78 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmjpegutils-2.1-0 amd64 1:2.1.0+debian-6build1 [24.1 kB]
# Get:79 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmodplug1 amd64 1:0.8.9.0-3 [153 kB]
# Get:80 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmpcdec6 amd64 2:0.1~r495-2 [32.4 kB]
# Get:81 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmpeg2encpp-2.1-0 amd64 1:2.1.0+debian-6build1 [69.4 kB]
# Get:82 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmplex2-2.1-0 amd64 1:2.1.0+debian-6build1 [44.4 kB]
# Get:83 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libnice10 amd64 0.1.18-2 [156 kB]
# Get:84 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libnotify4 amd64 0.7.9-3ubuntu5.22.04.1 [20.3 kB]
# Get:85 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenexr25 amd64 2.5.7-1 [780 kB]
# Get:86 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenh264-6 amd64 2.2.0+dfsg-2 [407 kB]
# Get:87 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenni2-0 amd64 2.2.0.33+dfsg-15 [389 kB]
# Get:88 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqrencode4 amd64 4.1.1-1 [24.0 kB]
# Get:89 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsecret-common all 0.20.5-2 [4278 B]
# Get:90 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsecret-1-0 amd64 0.20.5-2 [124 kB]
# Get:91 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsoundtouch1 amd64 2.3.1+ds1-1 [38.3 kB]
# Get:92 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libsoup-3.0-common all 3.0.7-0ubuntu1 [62.1 kB]
# Get:93 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libsoup-3.0-0 amd64 3.0.7-0ubuntu1 [278 kB]
# Get:94 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libspandsp2 amd64 0.0.6+dfsg-2 [272 kB]
# Get:95 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsrtp2-1 amd64 2.4.2-2 [40.7 kB]
# Get:96 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwebpdemux2 amd64 1.2.2-2ubuntu0.22.04.2 [9964 B]
# Get:97 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwebrtc-audio-processing1 amd64 0.3.1-0ubuntu5 [291 kB]
# Get:98 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libwildmidi2 amd64 0.4.3-1 [59.9 kB]
# Get:99 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwoff1 amd64 1.0.2-1build4 [45.2 kB]
# Get:100 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libxslt1-dev amd64 1.1.34-4ubuntu0.22.04.5 [219 kB]
# Get:101 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libxslt1.1 amd64 1.1.34-4ubuntu0.22.04.5 [165 kB]
# Get:102 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libzbar0 amd64 0.23.92-4build2 [121 kB]
# Get:103 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libzxingcore1 amd64 1.2.0-1 [619 kB]
# Get:104 http://archive.ubuntu.com/ubuntu jammy/universe amd64 xfonts-cyrillic all 1:1.0.5 [386 kB]
# Get:105 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-scalable all 1:1.0.3-1.2ubuntu1 [306 kB]
# Get:106 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdca0 amd64 0.0.7-2 [88.2 kB]
# Get:107 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libgstreamer-plugins-bad1.0-0 amd64 1.20.3-0ubuntu1.1 [489 kB]
# Get:108 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsbc1 amd64 1.5-3build2 [34.4 kB]
# Get:109 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libvo-aacenc0 amd64 0.1.3-2 [69.4 kB]
# Get:110 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libvo-amrwbenc0 amd64 0.1.3-2 [68.2 kB]
# Get:111 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 gstreamer1.0-plugins-bad amd64 1.20.3-0ubuntu1.1 [2602 kB]
# Get:112 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles2 amd64 1.4.0-1 [18.0 kB]
# Get:113 http://archive.ubuntu.com/ubuntu jammy/main amd64 libopengl0 amd64 1.4.0-1 [36.5 kB]
# debconf: delaying package configuration, since apt-utils is not installed
# Fetched 59.8 MB in 5s (12.0 MB/s)
# Selecting previously unselected package fonts-ipafont-gothic.
# (Reading database ... 104601 files and directories currently installed.)
# Preparing to unpack .../000-fonts-ipafont-gothic_00303-21ubuntu1_all.deb ...
# Unpacking fonts-ipafont-gothic (00303-21ubuntu1) ...
# Preparing to unpack .../001-libglib2.0-dev_2.72.4-0ubuntu2.8_amd64.deb ...
# Unpacking libglib2.0-dev:amd64 (2.72.4-0ubuntu2.8) over (2.72.4-0ubuntu2.6) ...
# Preparing to unpack .../002-libglib2.0-dev-bin_2.72.4-0ubuntu2.8_amd64.deb ...
# Unpacking libglib2.0-dev-bin (2.72.4-0ubuntu2.8) over (2.72.4-0ubuntu2.6) ...
# Preparing to unpack .../003-libglib2.0-bin_2.72.4-0ubuntu2.8_amd64.deb ...
# Unpacking libglib2.0-bin (2.72.4-0ubuntu2.8) over (2.72.4-0ubuntu2.6) ...
# Preparing to unpack .../004-libglib2.0-0_2.72.4-0ubuntu2.8_amd64.deb ...
# Unpacking libglib2.0-0:amd64 (2.72.4-0ubuntu2.8) over (2.72.4-0ubuntu2.6) ...
# Selecting previously unselected package libtext-iconv-perl.
# Preparing to unpack .../005-libtext-iconv-perl_1.7-7build3_amd64.deb ...
# Unpacking libtext-iconv-perl (1.7-7build3) ...
# Preparing to unpack .../006-libxml2-dev_2.9.13+dfsg-1ubuntu0.11_amd64.deb ...
# Unpacking libxml2-dev:amd64 (2.9.13+dfsg-1ubuntu0.11) over (2.9.13+dfsg-1ubuntu0.10) ...
# Preparing to unpack .../007-libxml2_2.9.13+dfsg-1ubuntu0.11_amd64.deb ...
# Unpacking libxml2:amd64 (2.9.13+dfsg-1ubuntu0.11) over (2.9.13+dfsg-1ubuntu0.10) ...
# Preparing to unpack .../008-libpng-dev_1.6.37-3ubuntu0.3_amd64.deb ...
# Unpacking libpng-dev:amd64 (1.6.37-3ubuntu0.3) over (1.6.37-3ubuntu0.1) ...
# Preparing to unpack .../009-libpng-tools_1.6.37-3ubuntu0.3_amd64.deb ...
# Unpacking libpng-tools (1.6.37-3ubuntu0.3) over (1.6.37-3ubuntu0.1) ...
# Preparing to unpack .../010-libpng16-16_1.6.37-3ubuntu0.3_amd64.deb ...
# Unpacking libpng16-16:amd64 (1.6.37-3ubuntu0.3) over (1.6.37-3ubuntu0.1) ...
# Selecting previously unselected package dictionaries-common.
# Preparing to unpack .../011-dictionaries-common_1.28.14_all.deb ...
# Adding 'diversion of /usr/share/dict/words to /usr/share/dict/words.pre-dictionaries-common by dictionaries-common'
# Unpacking dictionaries-common (1.28.14) ...
# Selecting previously unselected package fonts-freefont-ttf.
# Preparing to unpack .../012-fonts-freefont-ttf_20120503-10build1_all.deb ...
# Unpacking fonts-freefont-ttf (20120503-10build1) ...
# Selecting previously unselected package fonts-liberation.
# Preparing to unpack .../013-fonts-liberation_1%3a1.07.4-11_all.deb ...
# Unpacking fonts-liberation (1:1.07.4-11) ...
# Selecting previously unselected package fonts-noto-color-emoji.
# Preparing to unpack .../014-fonts-noto-color-emoji_2.047-0ubuntu0.22.04.1_all.deb ...
# Unpacking fonts-noto-color-emoji (2.047-0ubuntu0.22.04.1) ...
# Selecting previously unselected package fonts-tlwg-loma-otf.
# Preparing to unpack .../015-fonts-tlwg-loma-otf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-loma-otf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-unifont.
# Preparing to unpack .../016-fonts-unifont_1%3a14.0.01-1_all.deb ...
# Unpacking fonts-unifont (1:14.0.01-1) ...
# Selecting previously unselected package fonts-wqy-zenhei.
# Preparing to unpack .../017-fonts-wqy-zenhei_0.9.45-8_all.deb ...
# Unpacking fonts-wqy-zenhei (0.9.45-8) ...
# Selecting previously unselected package libproxy1v5:amd64.
# Preparing to unpack .../018-libproxy1v5_0.4.17-2_amd64.deb ...
# Unpacking libproxy1v5:amd64 (0.4.17-2) ...
# Selecting previously unselected package glib-networking-common.
# Preparing to unpack .../019-glib-networking-common_2.72.0-1_all.deb ...
# Unpacking glib-networking-common (2.72.0-1) ...
# Selecting previously unselected package glib-networking-services.
# Preparing to unpack .../020-glib-networking-services_2.72.0-1_amd64.deb ...
# Unpacking glib-networking-services (2.72.0-1) ...
# Selecting previously unselected package glib-networking:amd64.
# Preparing to unpack .../021-glib-networking_2.72.0-1_amd64.deb ...
# Unpacking glib-networking:amd64 (2.72.0-1) ...
# Selecting previously unselected package liborc-0.4-0:amd64.
# Preparing to unpack .../022-liborc-0.4-0_1%3a0.4.32-2ubuntu0.1_amd64.deb ...
# Unpacking liborc-0.4-0:amd64 (1:0.4.32-2ubuntu0.1) ...
# Selecting previously unselected package libgstreamer-plugins-base1.0-0:amd64.
# Preparing to unpack .../023-libgstreamer-plugins-base1.0-0_1.20.1-1ubuntu0.5_amd64.deb ...
# Unpacking libgstreamer-plugins-base1.0-0:amd64 (1.20.1-1ubuntu0.5) ...
# Selecting previously unselected package gstreamer1.0-libav:amd64.
# Preparing to unpack .../024-gstreamer1.0-libav_1.20.3-0ubuntu1_amd64.deb ...
# Unpacking gstreamer1.0-libav:amd64 (1.20.3-0ubuntu1) ...
# Selecting previously unselected package libcdparanoia0:amd64.
# Preparing to unpack .../025-libcdparanoia0_3.10.2+debian-14build2_amd64.deb ...
# Unpacking libcdparanoia0:amd64 (3.10.2+debian-14build2) ...
# Selecting previously unselected package libvisual-0.4-0:amd64.
# Preparing to unpack .../026-libvisual-0.4-0_0.4.0-17build2_amd64.deb ...
# Unpacking libvisual-0.4-0:amd64 (0.4.0-17build2) ...
# Selecting previously unselected package gstreamer1.0-plugins-base:amd64.
# Preparing to unpack .../027-gstreamer1.0-plugins-base_1.20.1-1ubuntu0.5_amd64.deb ...
# Unpacking gstreamer1.0-plugins-base:amd64 (1.20.1-1ubuntu0.5) ...
# Selecting previously unselected package libaa1:amd64.
# Preparing to unpack .../028-libaa1_1.4p5-50build1_amd64.deb ...
# Unpacking libaa1:amd64 (1.4p5-50build1) ...
# Selecting previously unselected package libdv4:amd64.
# Preparing to unpack .../029-libdv4_1.0.0-14build1_amd64.deb ...
# Unpacking libdv4:amd64 (1.0.0-14build1) ...
# Selecting previously unselected package libgstreamer-plugins-good1.0-0:amd64.
# Preparing to unpack .../030-libgstreamer-plugins-good1.0-0_1.20.3-0ubuntu1.4_amd64.deb ...
# Unpacking libgstreamer-plugins-good1.0-0:amd64 (1.20.3-0ubuntu1.4) ...
# Selecting previously unselected package libgudev-1.0-0:amd64.
# Preparing to unpack .../031-libgudev-1.0-0_1%3a237-2build1_amd64.deb ...
# Unpacking libgudev-1.0-0:amd64 (1:237-2build1) ...
# Selecting previously unselected package libshout3:amd64.
# Preparing to unpack .../032-libshout3_2.4.5-1build3_amd64.deb ...
# Unpacking libshout3:amd64 (2.4.5-1build3) ...
# Selecting previously unselected package libtag1v5-vanilla:amd64.
# Preparing to unpack .../033-libtag1v5-vanilla_1.11.1+dfsg.1-3ubuntu3_amd64.deb ...
# Unpacking libtag1v5-vanilla:amd64 (1.11.1+dfsg.1-3ubuntu3) ...
# Selecting previously unselected package libtag1v5:amd64.
# Preparing to unpack .../034-libtag1v5_1.11.1+dfsg.1-3ubuntu3_amd64.deb ...
# Unpacking libtag1v5:amd64 (1.11.1+dfsg.1-3ubuntu3) ...
# Selecting previously unselected package libv4lconvert0:amd64.
# Preparing to unpack .../035-libv4lconvert0_1.22.1-2build1_amd64.deb ...
# Unpacking libv4lconvert0:amd64 (1.22.1-2build1) ...
# Selecting previously unselected package libv4l-0:amd64.
# Preparing to unpack .../036-libv4l-0_1.22.1-2build1_amd64.deb ...
# Unpacking libv4l-0:amd64 (1.22.1-2build1) ...
# Selecting previously unselected package libwavpack1:amd64.
# Preparing to unpack .../037-libwavpack1_5.4.0-1build2_amd64.deb ...
# Unpacking libwavpack1:amd64 (5.4.0-1build2) ...
# Selecting previously unselected package libsoup2.4-common.
# Preparing to unpack .../038-libsoup2.4-common_2.74.2-3ubuntu0.6_all.deb ...
# Unpacking libsoup2.4-common (2.74.2-3ubuntu0.6) ...
# Selecting previously unselected package libsoup2.4-1:amd64.
# Preparing to unpack .../039-libsoup2.4-1_2.74.2-3ubuntu0.6_amd64.deb ...
# Unpacking libsoup2.4-1:amd64 (2.74.2-3ubuntu0.6) ...
# Selecting previously unselected package gstreamer1.0-plugins-good:amd64.
# Preparing to unpack .../040-gstreamer1.0-plugins-good_1.20.3-0ubuntu1.4_amd64.deb ...
# Unpacking gstreamer1.0-plugins-good:amd64 (1.20.3-0ubuntu1.4) ...
# Selecting previously unselected package hunspell-en-us.
# Preparing to unpack .../041-hunspell-en-us_1%3a2020.12.07-2_all.deb ...
# Unpacking hunspell-en-us (1:2020.12.07-2) ...
# Selecting previously unselected package libaspell15:amd64.
# Preparing to unpack .../042-libaspell15_0.60.8-4build1_amd64.deb ...
# Unpacking libaspell15:amd64 (0.60.8-4build1) ...
# Selecting previously unselected package libgav1-0:amd64.
# Preparing to unpack .../043-libgav1-0_0.17.0-1build1_amd64.deb ...
# Unpacking libgav1-0:amd64 (0.17.0-1build1) ...
# Selecting previously unselected package libyuv0:amd64.
# Preparing to unpack .../044-libyuv0_0.0~git20220104.b91df1a-2_amd64.deb ...
# Unpacking libyuv0:amd64 (0.0~git20220104.b91df1a-2) ...
# Selecting previously unselected package libavif13:amd64.
# Preparing to unpack .../045-libavif13_0.9.3-3_amd64.deb ...
# Unpacking libavif13:amd64 (0.9.3-3) ...
# Selecting previously unselected package liblzo2-2:amd64.
# Preparing to unpack .../046-liblzo2-2_2.10-2build3_amd64.deb ...
# Unpacking liblzo2-2:amd64 (2.10-2build3) ...
# Selecting previously unselected package libcairo-script-interpreter2:amd64.
# Preparing to unpack .../047-libcairo-script-interpreter2_1.16.0-5ubuntu2_amd64.deb ...
# Unpacking libcairo-script-interpreter2:amd64 (1.16.0-5ubuntu2) ...
# Selecting previously unselected package libdbus-glib-1-2:amd64.
# Preparing to unpack .../048-libdbus-glib-1-2_0.112-2build1_amd64.deb ...
# Unpacking libdbus-glib-1-2:amd64 (0.112-2build1) ...
# Selecting previously unselected package libde265-0:amd64.
# Preparing to unpack .../049-libde265-0_1.0.8-1ubuntu0.3_amd64.deb ...
# Unpacking libde265-0:amd64 (1.0.8-1ubuntu0.3) ...
# Selecting previously unselected package libdvdread8:amd64.
# Preparing to unpack .../050-libdvdread8_6.1.2-1_amd64.deb ...
# Unpacking libdvdread8:amd64 (6.1.2-1) ...
# Selecting previously unselected package libdvdnav4:amd64.
# Preparing to unpack .../051-libdvdnav4_6.1.1-1_amd64.deb ...
# Unpacking libdvdnav4:amd64 (6.1.1-1) ...
# Selecting previously unselected package libegl-mesa0:amd64.
# Preparing to unpack .../052-libegl-mesa0_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking libegl-mesa0:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Selecting previously unselected package libhunspell-1.7-0:amd64.
# Preparing to unpack .../053-libhunspell-1.7-0_1.7.0-4build1_amd64.deb ...
# Unpacking libhunspell-1.7-0:amd64 (1.7.0-4build1) ...
# Selecting previously unselected package libenchant-2-2:amd64.
# Preparing to unpack .../054-libenchant-2-2_2.3.2-1ubuntu2_amd64.deb ...
# Unpacking libenchant-2-2:amd64 (2.3.2-1ubuntu2) ...
# Selecting previously unselected package libfaad2:amd64.
# Preparing to unpack .../055-libfaad2_2.10.0-2_amd64.deb ...
# Unpacking libfaad2:amd64 (2.10.0-2) ...
# Selecting previously unselected package libinstpatch-1.0-2:amd64.
# Preparing to unpack .../056-libinstpatch-1.0-2_1.1.6-1_amd64.deb ...
# Unpacking libinstpatch-1.0-2:amd64 (1.1.6-1) ...
# Selecting previously unselected package timgm6mb-soundfont.
# Preparing to unpack .../057-timgm6mb-soundfont_1.3-5_all.deb ...
# Unpacking timgm6mb-soundfont (1.3-5) ...
# Selecting previously unselected package libfluidsynth3:amd64.
# Preparing to unpack .../058-libfluidsynth3_2.2.5-1_amd64.deb ...
# Unpacking libfluidsynth3:amd64 (2.2.5-1) ...
# Selecting previously unselected package libfreeaptx0:amd64.
# Preparing to unpack .../059-libfreeaptx0_0.1.1-1_amd64.deb ...
# Unpacking libfreeaptx0:amd64 (0.1.1-1) ...
# Selecting previously unselected package libgraphene-1.0-0:amd64.
# Preparing to unpack .../060-libgraphene-1.0-0_1.10.8-1_amd64.deb ...
# Unpacking libgraphene-1.0-0:amd64 (1.10.8-1) ...
# Selecting previously unselected package libgssdp-1.2-0:amd64.
# Preparing to unpack .../061-libgssdp-1.2-0_1.4.0.1-2build1_amd64.deb ...
# Unpacking libgssdp-1.2-0:amd64 (1.4.0.1-2build1) ...
# Selecting previously unselected package libegl1:amd64.
# Preparing to unpack .../062-libegl1_1.4.0-1_amd64.deb ...
# Unpacking libegl1:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgstreamer-gl1.0-0:amd64.
# Preparing to unpack .../063-libgstreamer-gl1.0-0_1.20.1-1ubuntu0.5_amd64.deb ...
# Unpacking libgstreamer-gl1.0-0:amd64 (1.20.1-1ubuntu0.5) ...
# Selecting previously unselected package libgtk-4-common.
# Preparing to unpack .../064-libgtk-4-common_4.6.9+ds-0ubuntu0.22.04.2_all.deb ...
# Unpacking libgtk-4-common (4.6.9+ds-0ubuntu0.22.04.2) ...
# Selecting previously unselected package libgtk-4-1:amd64.
# Preparing to unpack .../065-libgtk-4-1_4.6.9+ds-0ubuntu0.22.04.2_amd64.deb ...
# Unpacking libgtk-4-1:amd64 (4.6.9+ds-0ubuntu0.22.04.2) ...
# Selecting previously unselected package libgupnp-1.2-1:amd64.
# Preparing to unpack .../066-libgupnp-1.2-1_1.4.3-1_amd64.deb ...
# Unpacking libgupnp-1.2-1:amd64 (1.4.3-1) ...
# Selecting previously unselected package libgupnp-igd-1.0-4:amd64.
# Preparing to unpack .../067-libgupnp-igd-1.0-4_1.2.0-1build1_amd64.deb ...
# Unpacking libgupnp-igd-1.0-4:amd64 (1.2.0-1build1) ...
# Selecting previously unselected package libhyphen0:amd64.
# Preparing to unpack .../068-libhyphen0_2.8.8-7build2_amd64.deb ...
# Unpacking libhyphen0:amd64 (2.8.8-7build2) ...
# Selecting previously unselected package libilmbase25:amd64.
# Preparing to unpack .../069-libilmbase25_2.5.7-2_amd64.deb ...
# Unpacking libilmbase25:amd64 (2.5.7-2) ...
# Selecting previously unselected package libjson-glib-1.0-common.
# Preparing to unpack .../070-libjson-glib-1.0-common_1.6.6-1build1_all.deb ...
# Unpacking libjson-glib-1.0-common (1.6.6-1build1) ...
# Selecting previously unselected package libjson-glib-1.0-0:amd64.
# Preparing to unpack .../071-libjson-glib-1.0-0_1.6.6-1build1_amd64.deb ...
# Unpacking libjson-glib-1.0-0:amd64 (1.6.6-1build1) ...
# Selecting previously unselected package libkate1:amd64.
# Preparing to unpack .../072-libkate1_0.4.1-11build1_amd64.deb ...
# Unpacking libkate1:amd64 (0.4.1-11build1) ...
# Selecting previously unselected package libldacbt-enc2:amd64.
# Preparing to unpack .../073-libldacbt-enc2_2.0.2.3+git20200429+ed310a0-4_amd64.deb ...
# Unpacking libldacbt-enc2:amd64 (2.0.2.3+git20200429+ed310a0-4) ...
# Selecting previously unselected package libltc11:amd64.
# Preparing to unpack .../074-libltc11_1.3.1-1_amd64.deb ...
# Unpacking libltc11:amd64 (1.3.1-1) ...
# Selecting previously unselected package libevdev2:amd64.
# Preparing to unpack .../075-libevdev2_1.12.1+dfsg-1_amd64.deb ...
# Unpacking libevdev2:amd64 (1.12.1+dfsg-1) ...
# Selecting previously unselected package libmanette-0.2-0:amd64.
# Preparing to unpack .../076-libmanette-0.2-0_0.2.6-3build1_amd64.deb ...
# Unpacking libmanette-0.2-0:amd64 (0.2.6-3build1) ...
# Selecting previously unselected package libmjpegutils-2.1-0:amd64.
# Preparing to unpack .../077-libmjpegutils-2.1-0_1%3a2.1.0+debian-6build1_amd64.deb ...
# Unpacking libmjpegutils-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Selecting previously unselected package libmodplug1:amd64.
# Preparing to unpack .../078-libmodplug1_1%3a0.8.9.0-3_amd64.deb ...
# Unpacking libmodplug1:amd64 (1:0.8.9.0-3) ...
# Selecting previously unselected package libmpcdec6:amd64.
# Preparing to unpack .../079-libmpcdec6_2%3a0.1~r495-2_amd64.deb ...
# Unpacking libmpcdec6:amd64 (2:0.1~r495-2) ...
# Selecting previously unselected package libmpeg2encpp-2.1-0:amd64.
# Preparing to unpack .../080-libmpeg2encpp-2.1-0_1%3a2.1.0+debian-6build1_amd64.deb ...
# Unpacking libmpeg2encpp-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Selecting previously unselected package libmplex2-2.1-0:amd64.
# Preparing to unpack .../081-libmplex2-2.1-0_1%3a2.1.0+debian-6build1_amd64.deb ...
# Unpacking libmplex2-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Selecting previously unselected package libnice10:amd64.
# Preparing to unpack .../082-libnice10_0.1.18-2_amd64.deb ...
# Unpacking libnice10:amd64 (0.1.18-2) ...
# Selecting previously unselected package libnotify4:amd64.
# Preparing to unpack .../083-libnotify4_0.7.9-3ubuntu5.22.04.1_amd64.deb ...
# Unpacking libnotify4:amd64 (0.7.9-3ubuntu5.22.04.1) ...
# Selecting previously unselected package libopenexr25:amd64.
# Preparing to unpack .../084-libopenexr25_2.5.7-1_amd64.deb ...
# Unpacking libopenexr25:amd64 (2.5.7-1) ...
# Selecting previously unselected package libopenh264-6:amd64.
# Preparing to unpack .../085-libopenh264-6_2.2.0+dfsg-2_amd64.deb ...
# Unpacking libopenh264-6:amd64 (2.2.0+dfsg-2) ...
# Selecting previously unselected package libopenni2-0:amd64.
# Preparing to unpack .../086-libopenni2-0_2.2.0.33+dfsg-15_amd64.deb ...
# Unpacking libopenni2-0:amd64 (2.2.0.33+dfsg-15) ...
# Selecting previously unselected package libqrencode4:amd64.
# Preparing to unpack .../087-libqrencode4_4.1.1-1_amd64.deb ...
# Unpacking libqrencode4:amd64 (4.1.1-1) ...
# Selecting previously unselected package libsecret-common.
# Preparing to unpack .../088-libsecret-common_0.20.5-2_all.deb ...
# Unpacking libsecret-common (0.20.5-2) ...
# Selecting previously unselected package libsecret-1-0:amd64.
# Preparing to unpack .../089-libsecret-1-0_0.20.5-2_amd64.deb ...
# Unpacking libsecret-1-0:amd64 (0.20.5-2) ...
# Selecting previously unselected package libsoundtouch1:amd64.
# Preparing to unpack .../090-libsoundtouch1_2.3.1+ds1-1_amd64.deb ...
# Unpacking libsoundtouch1:amd64 (2.3.1+ds1-1) ...
# Selecting previously unselected package libsoup-3.0-common.
# Preparing to unpack .../091-libsoup-3.0-common_3.0.7-0ubuntu1_all.deb ...
# Unpacking libsoup-3.0-common (3.0.7-0ubuntu1) ...
# Selecting previously unselected package libsoup-3.0-0:amd64.
# Preparing to unpack .../092-libsoup-3.0-0_3.0.7-0ubuntu1_amd64.deb ...
# Unpacking libsoup-3.0-0:amd64 (3.0.7-0ubuntu1) ...
# Selecting previously unselected package libspandsp2:amd64.
# Preparing to unpack .../093-libspandsp2_0.0.6+dfsg-2_amd64.deb ...
# Unpacking libspandsp2:amd64 (0.0.6+dfsg-2) ...
# Selecting previously unselected package libsrtp2-1:amd64.
# Preparing to unpack .../094-libsrtp2-1_2.4.2-2_amd64.deb ...
# Unpacking libsrtp2-1:amd64 (2.4.2-2) ...
# Selecting previously unselected package libwebpdemux2:amd64.
# Preparing to unpack .../095-libwebpdemux2_1.2.2-2ubuntu0.22.04.2_amd64.deb ...
# Unpacking libwebpdemux2:amd64 (1.2.2-2ubuntu0.22.04.2) ...
# Selecting previously unselected package libwebrtc-audio-processing1:amd64.
# Preparing to unpack .../096-libwebrtc-audio-processing1_0.3.1-0ubuntu5_amd64.deb ...
# Unpacking libwebrtc-audio-processing1:amd64 (0.3.1-0ubuntu5) ...
# Selecting previously unselected package libwildmidi2:amd64.
# Preparing to unpack .../097-libwildmidi2_0.4.3-1_amd64.deb ...
# Unpacking libwildmidi2:amd64 (0.4.3-1) ...
# Selecting previously unselected package libwoff1:amd64.
# Preparing to unpack .../098-libwoff1_1.0.2-1build4_amd64.deb ...
# Unpacking libwoff1:amd64 (1.0.2-1build4) ...
# Preparing to unpack .../099-libxslt1-dev_1.1.34-4ubuntu0.22.04.5_amd64.deb ...
# Unpacking libxslt1-dev:amd64 (1.1.34-4ubuntu0.22.04.5) over (1.1.34-4ubuntu0.22.04.4) ...
# Preparing to unpack .../100-libxslt1.1_1.1.34-4ubuntu0.22.04.5_amd64.deb ...
# Unpacking libxslt1.1:amd64 (1.1.34-4ubuntu0.22.04.5) over (1.1.34-4ubuntu0.22.04.4) ...
# Selecting previously unselected package libzbar0:amd64.
# Preparing to unpack .../101-libzbar0_0.23.92-4build2_amd64.deb ...
# Unpacking libzbar0:amd64 (0.23.92-4build2) ...
# Selecting previously unselected package libzxingcore1:amd64.
# Preparing to unpack .../102-libzxingcore1_1.2.0-1_amd64.deb ...
# Unpacking libzxingcore1:amd64 (1.2.0-1) ...
# Selecting previously unselected package xfonts-cyrillic.
# Preparing to unpack .../103-xfonts-cyrillic_1%3a1.0.5_all.deb ...
# Unpacking xfonts-cyrillic (1:1.0.5) ...
# Selecting previously unselected package xfonts-scalable.
# Preparing to unpack .../104-xfonts-scalable_1%3a1.0.3-1.2ubuntu1_all.deb ...
# Unpacking xfonts-scalable (1:1.0.3-1.2ubuntu1) ...
# Selecting previously unselected package libdca0:amd64.
# Preparing to unpack .../105-libdca0_0.0.7-2_amd64.deb ...
# Unpacking libdca0:amd64 (0.0.7-2) ...
# Selecting previously unselected package libgstreamer-plugins-bad1.0-0:amd64.
# Preparing to unpack .../106-libgstreamer-plugins-bad1.0-0_1.20.3-0ubuntu1.1_amd64.deb ...
# Unpacking libgstreamer-plugins-bad1.0-0:amd64 (1.20.3-0ubuntu1.1) ...
# Selecting previously unselected package libsbc1:amd64.
# Preparing to unpack .../107-libsbc1_1.5-3build2_amd64.deb ...
# Unpacking libsbc1:amd64 (1.5-3build2) ...
# Selecting previously unselected package libvo-aacenc0:amd64.
# Preparing to unpack .../108-libvo-aacenc0_0.1.3-2_amd64.deb ...
# Unpacking libvo-aacenc0:amd64 (0.1.3-2) ...
# Selecting previously unselected package libvo-amrwbenc0:amd64.
# Preparing to unpack .../109-libvo-amrwbenc0_0.1.3-2_amd64.deb ...
# Unpacking libvo-amrwbenc0:amd64 (0.1.3-2) ...
# Selecting previously unselected package gstreamer1.0-plugins-bad:amd64.
# Preparing to unpack .../110-gstreamer1.0-plugins-bad_1.20.3-0ubuntu1.1_amd64.deb ...
# Unpacking gstreamer1.0-plugins-bad:amd64 (1.20.3-0ubuntu1.1) ...
# Selecting previously unselected package libgles2:amd64.
# Preparing to unpack .../111-libgles2_1.4.0-1_amd64.deb ...
# Unpacking libgles2:amd64 (1.4.0-1) ...
# Selecting previously unselected package libopengl0:amd64.
# Preparing to unpack .../112-libopengl0_1.4.0-1_amd64.deb ...
# Unpacking libopengl0:amd64 (1.4.0-1) ...
# Setting up libtext-iconv-perl (1.7-7build3) ...
# Setting up libfreeaptx0:amd64 (0.1.1-1) ...
# Setting up libmodplug1:amd64 (1:0.8.9.0-3) ...
# Setting up libcdparanoia0:amd64 (3.10.2+debian-14build2) ...
# Setting up libvo-amrwbenc0:amd64 (0.1.3-2) ...
# Setting up libsbc1:amd64 (1.5-3build2) ...
# Setting up libproxy1v5:amd64 (0.4.17-2) ...
# Setting up libtag1v5-vanilla:amd64 (1.11.1+dfsg.1-3ubuntu3) ...
# Setting up libkate1:amd64 (0.4.1-11build1) ...
# Setting up libopenni2-0:amd64 (2.2.0.33+dfsg-15) ...
# Setting up libwoff1:amd64 (1.0.2-1build4) ...
# Setting up libqrencode4:amd64 (4.1.1-1) ...
# Setting up libhyphen0:amd64 (2.8.8-7build2) ...
# Setting up dictionaries-common (1.28.14) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# Install emacsen-common for emacs
# emacsen-common: Handling install of emacsen flavor emacs
# Install dictionaries-common for emacs
# install/dictionaries-common: Byte-compiling for emacsen flavour emacs
# Setting up fonts-noto-color-emoji (2.047-0ubuntu0.22.04.1) ...
# Setting up libvisual-0.4-0:amd64 (0.4.0-17build2) ...
# Setting up libglib2.0-0:amd64 (2.72.4-0ubuntu2.8) ...
# Setting up libaspell15:amd64 (0.60.8-4build1) ...
# Setting up libwebpdemux2:amd64 (1.2.2-2ubuntu0.22.04.2) ...
# Setting up libsrtp2-1:amd64 (2.4.2-2) ...
# Setting up libldacbt-enc2:amd64 (2.0.2.3+git20200429+ed310a0-4) ...
# Setting up fonts-wqy-zenhei (0.9.45-8) ...
# Setting up libwebrtc-audio-processing1:amd64 (0.3.1-0ubuntu5) ...
# Setting up fonts-freefont-ttf (20120503-10build1) ...
# Setting up libglib2.0-bin (2.72.4-0ubuntu2.8) ...
# Setting up liblzo2-2:amd64 (2.10-2build3) ...
# Setting up libilmbase25:amd64 (2.5.7-2) ...
# Setting up libsoup-3.0-common (3.0.7-0ubuntu1) ...
# Setting up libmpcdec6:amd64 (2:0.1~r495-2) ...
# Setting up libopengl0:amd64 (1.4.0-1) ...
# Setting up libspandsp2:amd64 (0.0.6+dfsg-2) ...
# Setting up libvo-aacenc0:amd64 (0.1.3-2) ...
# Setting up libopenexr25:amd64 (2.5.7-1) ...
# Setting up libegl-mesa0:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up libsoundtouch1:amd64 (2.3.1+ds1-1) ...
# Setting up libgles2:amd64 (1.4.0-1) ...
# Setting up fonts-tlwg-loma-otf (1:0.7.3-1) ...
# Setting up libdvdread8:amd64 (6.1.2-1) ...
# Setting up libdbus-glib-1-2:amd64 (0.112-2build1) ...
# Setting up libnotify4:amd64 (0.7.9-3ubuntu5.22.04.1) ...
# Setting up libgav1-0:amd64 (0.17.0-1build1) ...
# Setting up libfaad2:amd64 (2.10.0-2) ...
# Setting up libshout3:amd64 (2.4.5-1build3) ...
# Setting up libpng16-16:amd64 (1.6.37-3ubuntu0.3) ...
# Setting up liborc-0.4-0:amd64 (1:0.4.32-2ubuntu0.1) ...
# Setting up libltc11:amd64 (1.3.1-1) ...
# Setting up libsoup2.4-common (2.74.2-3ubuntu0.6) ...
# Setting up libtag1v5:amd64 (1.11.1+dfsg.1-3ubuntu3) ...
# Setting up libdv4:amd64 (1.0.0-14build1) ...
# Setting up fonts-ipafont-gothic (00303-21ubuntu1) ...
# update-alternatives: using /usr/share/fonts/opentype/ipafont-gothic/ipag.ttf to provide /usr/share/fonts/truetype/fonts-japanese-gothic.ttf (fonts-japanese-gothic.ttf) in auto mode
# Setting up libwildmidi2:amd64 (0.4.3-1) ...
# Setting up libopenh264-6:amd64 (2.2.0+dfsg-2) ...
# Setting up libwavpack1:amd64 (5.4.0-1build2) ...
# Setting up xfonts-cyrillic (1:1.0.5) ...
# Setting up libzxingcore1:amd64 (1.2.0-1) ...
# Setting up libv4lconvert0:amd64 (1.22.1-2build1) ...
# Setting up fonts-liberation (1:1.07.4-11) ...
# Setting up libegl1:amd64 (1.4.0-1) ...
# Setting up hunspell-en-us (1:2020.12.07-2) ...
# Setting up libdca0:amd64 (0.0.7-2) ...
# Setting up libjson-glib-1.0-common (1.6.6-1build1) ...
# Setting up libgtk-4-common (4.6.9+ds-0ubuntu0.22.04.2) ...
# Setting up libhunspell-1.7-0:amd64 (1.7.0-4build1) ...
# Setting up glib-networking-common (2.72.0-1) ...
# Setting up libde265-0:amd64 (1.0.8-1ubuntu0.3) ...
# Setting up timgm6mb-soundfont (1.3-5) ...
# update-alternatives: using /usr/share/sounds/sf2/TimGM6mb.sf2 to provide /usr/share/sounds/sf2/default-GM.sf2 (default-GM.sf2) in auto mode
# update-alternatives: using /usr/share/sounds/sf2/TimGM6mb.sf2 to provide /usr/share/sounds/sf3/default-GM.sf3 (default-GM.sf3) in auto mode
# Setting up libyuv0:amd64 (0.0~git20220104.b91df1a-2) ...
# Setting up libevdev2:amd64 (1.12.1+dfsg-1) ...
# Setting up libxml2:amd64 (2.9.13+dfsg-1ubuntu0.11) ...
# Setting up libinstpatch-1.0-2:amd64 (1.1.6-1) ...
# Setting up libmjpegutils-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Setting up libgudev-1.0-0:amd64 (1:237-2build1) ...
# Setting up libsecret-common (0.20.5-2) ...
# Setting up xfonts-scalable (1:1.0.3-1.2ubuntu1) ...
# Setting up libgraphene-1.0-0:amd64 (1.10.8-1) ...
# Setting up libfluidsynth3:amd64 (2.2.5-1) ...
# Setting up libdvdnav4:amd64 (6.1.1-1) ...
# Setting up fonts-unifont (1:14.0.01-1) ...
# Setting up libaa1:amd64 (1.4p5-50build1) ...
# Setting up libcairo-script-interpreter2:amd64 (1.16.0-5ubuntu2) ...
# Setting up libglib2.0-dev-bin (2.72.4-0ubuntu2.8) ...
# Setting up glib-networking-services (2.72.0-1) ...
# Setting up libpng-tools (1.6.37-3ubuntu0.3) ...
# Setting up libenchant-2-2:amd64 (2.3.2-1ubuntu2) ...
# Setting up libmanette-0.2-0:amd64 (0.2.6-3build1) ...
# Setting up libpng-dev:amd64 (1.6.37-3ubuntu0.3) ...
# Setting up libgstreamer-plugins-base1.0-0:amd64 (1.20.1-1ubuntu0.5) ...
# Setting up libjson-glib-1.0-0:amd64 (1.6.6-1build1) ...
# Setting up libv4l-0:amd64 (1.22.1-2build1) ...
# Setting up libgstreamer-plugins-bad1.0-0:amd64 (1.20.3-0ubuntu1.1) ...
# Setting up libxml2-dev:amd64 (2.9.13+dfsg-1ubuntu0.11) ...
# Setting up libsecret-1-0:amd64 (0.20.5-2) ...
# Setting up libgstreamer-plugins-good1.0-0:amd64 (1.20.3-0ubuntu1.4) ...
# Setting up libgstreamer-gl1.0-0:amd64 (1.20.1-1ubuntu0.5) ...
# Setting up gstreamer1.0-plugins-base:amd64 (1.20.1-1ubuntu0.5) ...
# Setting up libglib2.0-dev:amd64 (2.72.4-0ubuntu2.8) ...
# Setting up libmpeg2encpp-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Setting up libavif13:amd64 (0.9.3-3) ...
# Setting up libgtk-4-1:amd64 (4.6.9+ds-0ubuntu0.22.04.2) ...
# Setting up libxslt1.1:amd64 (1.1.34-4ubuntu0.22.04.5) ...
# Setting up libmplex2-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Setting up glib-networking:amd64 (2.72.0-1) ...
# Setting up gstreamer1.0-libav:amd64 (1.20.3-0ubuntu1) ...
# Setting up libsoup2.4-1:amd64 (2.74.2-3ubuntu0.6) ...
# Setting up libxslt1-dev:amd64 (1.1.34-4ubuntu0.22.04.5) ...
# Setting up libzbar0:amd64 (0.23.92-4build2) ...
# Setting up gstreamer1.0-plugins-good:amd64 (1.20.3-0ubuntu1.4) ...
# Setting up libsoup-3.0-0:amd64 (3.0.7-0ubuntu1) ...
# Setting up libgssdp-1.2-0:amd64 (1.4.0.1-2build1) ...
# Setting up libgupnp-1.2-1:amd64 (1.4.3-1) ...
# Setting up libgupnp-igd-1.0-4:amd64 (1.2.0-1build1) ...
# Setting up libnice10:amd64 (0.1.18-2) ...
# Setting up gstreamer1.0-plugins-bad:amd64 (1.20.3-0ubuntu1.1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.11) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for dictionaries-common (1.28.14) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# Successfully installed Playwright and dependencies.

# %% [markdown]
# ## Configuration & Constants

# %%
WC_SCHEDULE_URL = "https://www.mlssoccer.com/news/fifa-world-cup-2026-schedule-every-game-by-city-stadium"
LATLONG_URL = "https://www.latlong.net/location/2026-fifa-world-cup-locations-2252"
HEADERS = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"}

DELTA_TABLE_NAME = "world_cup_anastasia"

COUNTRIES = {"United States", "Canada", "Mexico"}
STADIUM_SYNONYMS = {
    "Estadio Azteca": "Estadio Banorte", 
    "Mexico City Stadium": "Estadio Banorte",
    "Hard Rock Stadium": "Hard Rock Stadium",
    "Gillette Stadium": "Gillette Stadium",
    "MetLife Stadium": "MetLife Stadium",
    "Mercedes-Benz Stadium": "Mercedes-Benz Stadium"
}

MONTH_RE = re.compile(r"^(?:[\u2022•\*\-\u2013\u2014]*\s*)?(June|July)\s+(\d{1,2})(?::)?\s*(.*)$")
STADIUM_HDR_RE = re.compile(r"^(?P<city>.+?)\s*[\-\u2013\u2014]\s*(?P<stadium>.+)$")
PACKED_LATLON_RE = re.compile(r"^\s*([+\-]?\d+(?:\.\d+)?)([+\-]\d+(?:\.\d+)?)\s*$")

# %% [markdown]
# # Core Data Pipeline: Scraping & Parsing

# %% [markdown]
# ## Network Utility Functions

# %%
# Setup basic logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

def get_html_static(url: str) -> str:
    """
    Fetches HTML content using standard HTTP requests.
    Best for static pages like LatLong.net.
    """
    try:
        logger.info(f"Fetching static HTML from: {url}")
        response = requests.get(url, headers=HEADERS, timeout=30)
        response.raise_for_status()
        return response.text
    except requests.RequestException as e:
        logger.error(f"Failed to fetch {url}: {e}")
        raise

async def get_html_dynamic(url: str) -> str:
    """
    Fetches HTML content using a headless browser (Playwright).
    Necessary for the MLS site which may use JavaScript or require cookie consent.
    """
    logger.info(f"Launching Playwright for: {url}")
    
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        context = await browser.new_context(viewport={'width': 1920, 'height': 1080})
        page = await context.new_page()
        
        try:
            await page.goto(url, wait_until='domcontentloaded', timeout=60000)
            
            # Attempt to handle cookie consent popups if they exist
            try:
                consent_button = page.locator("button:has-text('Accept'), button:has-text('Consent')").first
                if await consent_button.is_visible():
                    await consent_button.click(timeout=5000)
                    logger.info("Clicked cookie consent button.")
            except Exception:
                logger.debug("No cookie consent button found or needed.")

            await page.wait_for_selector('main', timeout=60000)
            await page.wait_for_timeout(2000) 
            
            html_content = await page.content()
            return html_content
            
        except Exception as e:
            logger.error(f"Playwright error on {url}: {e}")
            raise
        finally:
            await browser.close()

# %% [markdown]
# ## Parsing Logic Functions

# %%
def parse_packed_latlon(coords_str: str) -> tuple[Optional[float], Optional[float]]:
    if not coords_str: return None, None
    coords_str = str(coords_str).strip()
    match = PACKED_LATLON_RE.match(coords_str)
    if match:
        return float(match.group(1)), float(match.group(2))
    return None, None

def parse_stadium_coords(html: str) -> pd.DataFrame:
    try:
        tables = pd.read_html(StringIO(html))
        if not tables: return pd.DataFrame()
        df = tables[0].copy()
        df.columns = [str(c).strip().lower() for c in df.columns]
        name_col = next((c for c in ["location name", "location", "name"] if c in df.columns), df.columns[0])
        lat_col = "latitude" if "latitude" in df.columns else df.columns[1]
        lon_col = "longitude" if "longitude" in df.columns else None
        results = []
        for _, row in df.iterrows():
            stadium = str(row[name_col]).strip()
            lat_raw = str(row[lat_col]).strip()
            lat, lon = None, None
            if lon_col and pd.notna(row.get(lon_col)):
                try:
                    lat, lon = float(lat_raw), float(row[lon_col])
                except ValueError:
                    lat, lon = parse_packed_latlon(lat_raw)
            else:
                lat, lon = parse_packed_latlon(lat_raw)
            if lat is not None:
                results.append({"stadium": stadium, "lat": lat, "lon": lon})
        return pd.DataFrame(results).drop_duplicates(subset=["stadium"])
    except Exception as e:
        print(f"Error parsing coords: {e}")
        return pd.DataFrame()

def parse_world_cup_schedule(html: str) -> pd.DataFrame:
    soup = BeautifulSoup(html, "html.parser")
    main_content = soup.find("main") or soup
    text = main_content.get_text("\n")
    lines = [line.replace("\xa0", " ").strip() for line in text.splitlines() if line.strip()]
    
    match_rows = []
    line_index = 0
    
    current_city = None
    current_country = None
    current_stadium = None
    current_phase = "Group Stage"
    
    STADIUM_KEYWORDS = ["Stadium", "Field", "Estadio", "BC Place", "BMO Field", "Arena"]

    while line_index < len(lines):
        line = lines[line_index]
        
        is_date_line = line.startswith("June") or line.startswith("July")
        header_match = STADIUM_HDR_RE.match(line)
        is_third_place_line = "Third Place" in line or "Bronze" in line
        
        if header_match and not is_date_line and not is_third_place_line:
            stadium_part = header_match.group("stadium")
            if any(k in stadium_part for k in STADIUM_KEYWORDS):
                current_city = header_match.group("city").strip()
                current_stadium = stadium_part.strip()
                if "," in current_city: 
                    current_city = current_city.split(",")[0].strip()
                if line_index + 1 < len(lines) and lines[line_index+1] in COUNTRIES:
                    current_country = lines[line_index+1]
                line_index += 1
                continue

        if line in ["Group Stage", "Knockout Stage"]:
            current_phase = line
            line_index += 1
            continue
            
        date_match = MONTH_RE.match(line)
        if date_match and current_stadium:
            month, day, raw_details = date_match.groups()
            match_date = f"{month} {day}, 2026"
            raw_details = raw_details.strip() if raw_details else ""
            
            if not raw_details and (line_index + 1 < len(lines)):
                next_line = lines[line_index + 1].strip()
                is_next_header = STADIUM_HDR_RE.match(next_line) and any(k in next_line for k in STADIUM_KEYWORDS)
                is_next_third_place = "Third Place" in next_line or "Bronze" in next_line
                
                if (not is_next_header or is_next_third_place) and next_line not in COUNTRIES:
                    raw_details = next_line
                    line_index += 1 
            
            if raw_details:
                group_info = "Group Stage" if current_phase == "Group Stage" else current_phase
                teams_info = raw_details
                if " | " in raw_details:
                    parts = raw_details.split(" | ", 1)
                    group_info = parts[0].strip()
                    teams_info = parts[1].strip()
                elif "(" in raw_details and raw_details.endswith(")"):
                    parts = raw_details.split("(")
                    teams_info = parts[0].strip()
                    group_info = parts[1].replace(")", "").strip()

                match_rows.append({
                    "Date": match_date,
                    "City": current_city,
                    "Country": current_country,
                    "Stadium": current_stadium,
                    "Phase": current_phase,
                    "Group_Stage": group_info,
                    "Match_Teams": teams_info,
                    "Stadium_Key": STADIUM_SYNONYMS.get(current_stadium, current_stadium)
                })
            
        line_index += 1
        
    return pd.DataFrame(match_rows)

# %% [markdown]
# ## Pipeline Execution

# %% [markdown]
# ### Fetch Data

# %%
# Fetch World Cup 2026 Data
print("Fetching World Cup 2026 Schedule...")
loop = asyncio.get_event_loop()
raw_schedule_html = loop.run_until_complete(get_html_dynamic(WC_SCHEDULE_URL))

# Fetch LatLong Data
print("Fetching Coordinates...")
raw_latlong_html = get_html_static(LATLONG_URL)

print("Fetching complete.")
print(f"Schedule HTML Length: {len(raw_schedule_html)} chars")
print(f"LatLong HTML Length: {len(raw_latlong_html)} chars")
# Out:
# Fetching World Cup 2026 Schedule...
# Fetching Coordinates...
# Fetching complete.
# Schedule HTML Length: 424642 chars
# LatLong HTML Length: 37160 chars

# %% [markdown]
# ### Parse, Merge & Save

# %%
# Parsing
print("Parsing World Cup matches...")
df_matches = parse_world_cup_schedule(raw_schedule_html)
print(f"Found {len(df_matches)} matches.")

print("Parsing coordinates...")
df_coords = parse_stadium_coords(raw_latlong_html)
print(f"Found {len(df_coords)} locations.")

# Merging
print("Merging Data...")
df_final = df_matches.merge(
    df_coords, 
    left_on="Stadium_Key", 
    right_on="stadium", 
    how="left"
)

# Clean & Rename
df_final = df_final.rename(columns={
    "Date": "date",
    "City": "city",
    "Country": "country",
    "Stadium": "stadium_name",
    "Phase": "phase",
    "Group_Stage": "group_or_stage",
    "Match_Teams": "match_teams",
    "lat": "latitude",
    "lon": "longitude"
})
final_cols = ["date", "city", "country", "stadium_name", "phase", "group_or_stage", "match_teams", "latitude", "longitude"]
df_final = df_final[final_cols]

# Save to Delta
print(f"Saving to Delta Table: {DELTA_TABLE_NAME}")
spark_df = spark.createDataFrame(df_final)
(spark_df.write
    .format("delta")
    .mode("overwrite")
    .partitionBy("city")
    .option("overwriteSchema", "true")
    .saveAsTable(DELTA_TABLE_NAME)
)

print(f"Success! {spark.table(DELTA_TABLE_NAME).count()} matches saved.")
display(spark.table(DELTA_TABLE_NAME))
# Out:
# Parsing World Cup matches...
# Found 104 matches.
# Parsing coordinates...
# Found 16 locations.
# Merging Data...
# Saving to Delta Table: world_cup_anastasia
# Success! 104 matches saved.
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>city</th><th>country</th><th>stadium_name</th><th>phase</th><th>group_or_stage</th><th>match_teams</th><th>latitude</th><th>longitude</th></tr></thead><tbody><tr><td>June 15, 2026</td><td>Atlanta</td><td>United States</td><td>Mercedes-Benz Stadium</td><td>Group Stage</td><td>Spain vs. Cape Verde</td><td>Group H</td><td>33.755371</td><td>-84.401436</td></tr><tr><td>June 18, 2026</td><td>Atlanta</td><td>United States</td><td>Mercedes-Benz Stadium</td><td>Group Stage</td><td>UEFA Playoff D Winner vs. South Africa</td><td>Group A</td><td>33.755371</td><td>-84.401436</td></tr><tr><td>June 21, 2026</td><td>Atlanta</td><td>United States</td><td>Mercedes-Benz Stadium</td><td>Group Stage</td><td>Spain vs. Saudi Arabia</td><td>Group H</td><td>33.755371</td><td>-84.401436</td></tr><tr><td>June 24, 2026</td><td>Atlanta</td><td>United States</td><td>Mercedes-Benz Stadium</td><td>Group Stage</td><td>Morocco vs. Haiti</td><td>Group C</td><td>33.755371</td><td>-84.401436</td></tr><tr><td>June 27, 2026</td><td>Atlanta</td><td>United States</td><td>Mercedes-Benz Stadium</td><td>Group Stage</td><td>Intercontinental Playoff 1 Winner vs. Uzbekistan</td><td>Group K</td><td>33.755371</td><td>-84.401436</td></tr><tr><td>July 1, 2026</td><td>Atlanta</td><td>United States</td><td>Mercedes-Benz Stadium</td><td>Knockout Stage</td><td>Round of 32</td><td>Group L Winner vs. Group E/H/I/J/K third place</td><td>33.755371</td><td>-84.401436</td></tr><tr><td>July 7, 2026</td><td>Atlanta</td><td>United States</td><td>Mercedes-Benz Stadium</td><td>Knockout Stage</td><td>Round of 16</td><td>Winner Match 86 vs. Winner Match 88</td><td>33.755371</td><td>-84.401436</td></tr><tr><td>July 15, 2026</td><td>Atlanta</td><td>United States</td><td>Mercedes-Benz Stadium</td><td>Knockout Stage</td><td>Semifinals</td><td>Winner Match 99 vs. Winner Match 100</td><td>33.755371</td><td>-84.401436</td></tr><tr><td>June 16, 2026</td><td>Kansas City</td><td>United States</td><td>GEHA Field at Arrowhead Stadium</td><td>Group Stage</td><td>Argentina vs. Algeria</td><td>Group J</td><td>39.048855</td><td>-94.484474</td></tr><tr><td>June 20, 2026</td><td>Kansas City</td><td>United States</td><td>GEHA Field at Arrowhead Stadium</td><td>Group Stage</td><td>Ecuador vs. Curaçao</td><td>Group E</td><td>39.048855</td><td>-94.484474</td></tr><tr><td>June 25, 2026</td><td>Kansas City</td><td>United States</td><td>GEHA Field at Arrowhead Stadium</td><td>Group Stage</td><td>Tunisia vs. Netherlands</td><td>Group F</td><td>39.048855</td><td>-94.484474</td></tr><tr><td>June 27, 2026</td><td>Kansas City</td><td>United States</td><td>GEHA Field at Arrowhead Stadium</td><td>Group Stage</td><td>Algeria vs. Austria</td><td>Group J</td><td>39.048855</td><td>-94.484474</td></tr><tr><td>July 3, 2026</td><td>Kansas City</td><td>United States</td><td>GEHA Field at Arrowhead Stadium</td><td>Knockout Stage</td><td>Round of 32</td><td>Group K Winner vs. Group D/E/I/J/L third place</td><td>39.048855</td><td>-94.484474</td></tr><tr><td>July 11, 2026</td><td>Kansas City</td><td>United States</td><td>GEHA Field at Arrowhead Stadium</td><td>Knockout Stage</td><td>Quarterfinals</td><td>Winner Match 95 vs. Winner Match 96</td><td>39.048855</td><td>-94.484474</td></tr><tr><td>June 12, 2026</td><td>Los Angeles</td><td>United States</td><td>SoFi Stadium</td><td>Group Stage</td><td>USA vs. Paraguay</td><td>Group D</td><td>33.953438</td><td>-118.339447</td></tr><tr><td>June 15, 2026</td><td>Los Angeles</td><td>United States</td><td>SoFi Stadium</td><td>Group Stage</td><td>Iran vs. New Zealand</td><td>Group G</td><td>33.953438</td><td>-118.339447</td></tr><tr><td>June 18, 2026</td><td>Los Angeles</td><td>United States</td><td>SoFi Stadium</td><td>Group Stage</td><td>Switzerland vs. UEFA Playoff A Winner</td><td>Group B</td><td>33.953438</td><td>-118.339447</td></tr><tr><td>June 21, 2026</td><td> ...
